# %%
#!/usr/bin/env python3
import os
import ethercalc
import datetime
import pytz


sheet_id = 'dzcw69d7tor3'
e = ethercalc.EtherCalc("https://ethercalc.net")

for i in range(1,100):
    status = e.cells(sheet_id, "S"+str(i))["datavalue"]
    print(status)
    if status == 'w':
        d = e.cells(sheet_id, "A"+str(i))["datavalue"]
        D = e.cells(sheet_id, "B"+str(i))["datavalue"]
        r = e.cells(sheet_id, "C"+str(i))["datavalue"]
        m_1 = e.cells(sheet_id, "D"+str(i))["datavalue"]
        h = e.cells(sheet_id, "E"+str(i))["datavalue"]
        X = e.cells(sheet_id, "F"+str(i))["datavalue"]
        PARA = e.cells(sheet_id, "G"+str(i))["datavalue"]
        
        str_d = str(d)
        str_D = str(D)
        str_r = str(r)
        str_m_1 = str(m_1)
        str_h = str(h)
        str_X = str(X)
        str_PARA = str(PARA)
        
        output_file = "../output/out_"+str_d+"_"+str_X+"_"+str_PARA+".ipynb"
        parameters = " -p d "+ str_d+"  -p D "+ str_D+" -p r " + str_r+" -p m_1 " + str_m_1+" -p h " + str_h+" -p X " + str_X+" -p PARA " + str_PARA
        cmd = ["papermill", "img_quadratic_principal_papermill_template.ipynb", output_file, parameters,  "-k sagemath", "--autosave-cell-every 30" , "--progress-bar"]
        str_cmd = '  '.join(cmd)
        print(str_cmd)
        e.command(sheet_id, [ethercalc.set("S"+str(i), "'r")])
        os.system(str_cmd)
        e.command(sheet_id, [ ethercalc.set("S"+str(i), "'d")])
        e.command(sheet_id, [ ethercalc.set("T"+str(i), "'" + str(datetime.datetime.now(tz=pytz.timezone('Asia/Tokyo'))))])
# Out:
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-5_10^10_100.ipynb   -p d -5  -p D -20 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-6_10^10_100.ipynb   -p d -6  -p D -24 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-5_10^10_100.ipynb   -p d -5  -p D -20 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-6_10^10_100.ipynb   -p d -6  -p D -24 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-5_10^10_100.ipynb   -p d -5  -p D -20 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-6_10^10_100.ipynb   -p d -6  -p D -24 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-10_10^10_100.ipynb   -p d -10  -p D -40 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-13_10^10_100.ipynb   -p d -13  -p D -52 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-14_10^10_100.ipynb   -p d -14  -p D -56 -p r 2 -p m_1 0 -p h 4 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-15_10^10_100.ipynb   -p d -15  -p D -15 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-17_10^10_100.ipynb   -p d -17  -p D -68 -p r 2 -p m_1 0 -p h 4 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-21_10^10_100.ipynb   -p d -21  -p D -84 -p r 3 -p m_1 0 -p h 4 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-105_10^10_100.ipynb   -p d -105  -p D -420 -p r 4 -p m_1 0 -p h 8 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-1155_10^10_100.ipynb   -p d -1155  -p D -1155 -p r 4 -p m_1 0 -p h 8 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-15015_10^10_100.ipynb   -p d -15015  -p D -15015 -p r 5 -p m_1 0 -p h 96 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-255255_10^10_100.ipynb   -p d -255255  -p D -255255 -p r 6 -p m_1 0 -p h 256 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-4849845_10^10_100.ipynb   -p d -4849845  -p D -19399380 -p r 8 -p m_1 0 -p h 1536 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-111546435_10^10_100.ipynb   -p d -111546435  -p D -111546435 -p r 8 -p m_1 0 -p h 2688 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-3234846615_10^10_100.ipynb   -p d -3234846615  -p D -3234846615 -p r 9 -p m_1 0 -p h 39424 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-22_10^10_100.ipynb   -p d -22  -p D -88 -p r 2 -p m_1 0 -p h 2 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-23_10^10_100.ipynb   -p d -23  -p D -23 -p r 1 -p m_1 0 -p h 3 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-26_10^10_100.ipynb   -p d -26  -p D -104 -p r 2 -p m_1 0 -p h 6 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-29_10^10_100.ipynb   -p d -29  -p D -116 -p r 2 -p m_1 0 -p h 6 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-30_10^10_100.ipynb   -p d -30  -p D -120 -p r 3 -p m_1 0 -p h 4 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-31_10^10_100.ipynb   -p d -31  -p D -31 -p r 1 -p m_1 0 -p h 3 -p X 10^10 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
# n
# n
# n
# w
# papermill  img_quadratic_principal_papermill_template.ipynb  ../output/out_-255255_10^11_100.ipynb   -p d -255255  -p D -255255 -p r 6 -p m_1 0 -p h 256 -p X 10^11 -p PARA 100  -k sagemath  --autosave-cell-every 30  --progress-bar
